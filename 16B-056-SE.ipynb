# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as calgraph
import time
import sys


if __name__ == "__main__":
    main()
        

def main():
    sys.setrecursionlimit(50000)
    print("Welcome!\n1. Open\n2. High\n3. Low\n4. Close")
    print("Enter your choice :")
    dataset=pd.read_csv("data.csv")
    
    arr_time1 = [0]
    arr_time2 = [0]
    arr_time3 = [0]
    
    arr_size1 = [0]
    arr_size2 = [0]
    arr_size3 = [0]
    
    user_data =  int (input())
    if (user_data ==1):
        arraydata= dataset[:1].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,2]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        calgraph.safigure(figsize=(8,5))
        calgraph.title(' Insertion Sort vs Quick Sort vs Merge Sort', fontdict={'fontweight':'bold', 'fontsize': 18})
        calgraph.plot(arr_size1, arr_time1, color='blue', label='INSERTION')
        calgraph.plot(arr_size2, arr_time2, color='yellow', label='QUICK')
        calgraph.plot(arr_size3, arr_time3, color='green',label='MERGE')
        calgraph.xlabel('N')
        calgraph.ylabel('Time (s)')
        calgraph.legend()
        calgraph.savefig('graph.png', dpi=300)
        print("Have a nice day!")
        
        
        
    elif (user_data ==2):
        
        arraydata= dataset[:1].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,3]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        calgraph.safigure(figsize=(8,5))
        calgraph.title(' Insertion Sort vs Quick Sort vs Merge Sort', fontdict={'fontweight':'bold', 'fontsize': 18})
        calgraph.plot(arr_size1, arr_time1, color='blue', label='INSERTION')
        calgraph.plot(arr_size2, arr_time2, color='yellow', label='QUICK')
        calgraph.plot(arr_size3, arr_time3, color='green',label='MERGE')
        calgraph.xlabel('N')
        calgraph.ylabel('Time (s)')
        calgraph.legend()
        calgraph.savefig('graph.png', dpi=300)
        print("Have a nice day!")
        
        
    elif (user_daa == 3 ):
        
        arraydata= dataset[:1].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,4]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        calgraph.safigure(figsize=(8,5))
        calgraph.title(' Insertion Sort vs Quick Sort vs Merge Sort', fontdict={'fontweight':'bold', 'fontsize': 18})
        calgraph.plot(arr_size1, arr_time1, color='blue', label='INSERTION')
        calgraph.plot(arr_size2, arr_time2, color='yellow', label='QUICK')
        calgraph.plot(arr_size3, arr_time3, color='green',label='MERGE')
        calgraph.xlabel('N')
        calgraph.ylabel('Time (s)')
        calgraph.legend()
        calgraph.savefig('graph.png', dpi=300)
        print("Have a nice day!")
        
        
    elif (user_data == 4):
        
        arraydata= dataset[:1].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        insertionSort(data)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size1.append(n)
        
        arraydata= dataset[:1].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time1.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        quickSort(data,0,n-1)
        finsh = time.time()
        arr_time2.append(finsh-begins)
        arr_size2.append(n)
        
        arraydata= dataset[:100].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:1000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:5000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:10000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:15000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:20000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:25000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:30000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:35000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:40000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:45000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        arraydata= dataset[:50000].values
        data=arraydata[:,5]
        n=len(data)
        begins = time.time()
        mergeSort(data,0,n-1)
        finsh = time.time()
        arr_time3.append(finsh-begins)
        arr_size3.append(n)
        
        calgraph.safigure(figsize=(8,5))
        calgraph.title(' Insertion Sort vs Quick Sort vs Merge Sort', fontdict={'fontweight':'bold', 'fontsize': 18})
        calgraph.plot(arr_size1, arr_time1, color='blue', label='INSERTION')
        calgraph.plot(arr_size2, arr_time2, color='yellow', label='QUICK')
        calgraph.plot(arr_size3, arr_time3, color='green',label='MERGE')
        calgraph.xlabel('N')
        calgraph.ylabel('Time (s)')
        calgraph.legend()
        calgraph.savefig('graph.png', dpi=300)
        print("Have a nice day!")
        
        
    else:
        print("invalid Input")
    
        def mergeSort(arr,l,r): 
            
            if l < r: 
                
                m = (l+(r-1))//2
                mergeSort(arr, l, m) 
                mergeSort(arr, m+1, r) 
                merge(arr, l, m, r) 
        
        def merge(arr, l, m, r): 
            n1 = m - l + 1
            n2 = r- m 
            L = [0] * (n1) 
            R = [0] * (n2) 
            for i in range(0 , n1): 
                L[i] = arr[l + i] 
                for j in range(0 , n2): 
                    R[j] = arr[m + 1 + j] 
                    i = 0      
                    j = 0     
                    k = l     
            
            while i < n1 and j < n2 : 
                if L[i] <= R[j]: 
                    arr[k] = L[i] 
                    i += 1
                else: 
                    arr[k] = R[j] 
                    j += 1
                    k += 1
            
            while i < n1:
                arr[k] = L[i] 
                i += 1
                k += 1
            
            while j < n2:
                arr[k] = R[j] 
                j += 1
                k += 1
                
        def quickSort(arr,low,high):
            if low < high:
                pi = partition(arr,low,high)
                quickSort(arr, low, pi-1)
                quickSort(arr, pi+1, high)
        
        def partition(arr,low,high):
            i = ( low-1 )        
            pivot = arr[high]    
            
            for j in range(low , high):
                if   arr[j] <= pivot:
                    i = i+1
                    arr[i],arr[j] = arr[j],arr[i]
                    arr[i+1],arr[high] = arr[high],arr[i+1]
                    
                    return ( i+1 )
        
        def insertionSort(arr): 
            for i in range(1, len(arr)):
                key = arr[i] 
                j = i-1
                while j >= 0 and key < arr[j] : 
                    arr[j + 1] = arr[j] 
                    j -= 1
                    arr[j + 1] = key
# Out:
# Welcome!
# 1. Open
# 2. High
# 3. Low
# 4. Close
# Enter your choice :
# 1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-0bb0a901cd0a> in <module>
#       7
#       8 if __name__ == "__main__":
# ----> 9     main()
#      10
#      11
#
# <ipython-input-1-71328d450d9d> in main()
#      26         n=len(data)
#      27         begins = time.time()
# ---> 28         insertionSort(data)
#      29         finsh = time.time()
#      30         arr_time1.append(finsh-begins)
#
# UnboundLocalError: local variable 'insertionSort' referenced before assignment
