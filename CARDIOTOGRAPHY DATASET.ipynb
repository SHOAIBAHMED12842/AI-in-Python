# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plotaccuracy
import matplotlib.pyplot as plotfmeasure
import matplotlib.pyplot as plotgraph
from sklearn.metrics import f1_score
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import svm
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import chi2_kernel
from sklearn.model_selection import cross_val_score

dataset=pd.read_excel("cardiotography.xlsx")
acck = []
accnb = []
accsv=[]
accc4 = []
accrbf=[]
sizek=[]
sizenb=[]
sizesv=[]
sizec4=[]
sizerbf=[]
#--------------------------------KNN----------------------------------

#----------------------knn 600----------------

array= dataset[:600].values
#array= dataset.values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizek.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    
print("\nBy using KNN Classifier \n")
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(normalized_X_train,Y_train)
predictions=knn.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc1=accuracy_score(Y_test,predictions)
acck.append(acc1)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f1=f1_score(Y_test, predictions, average="macro")
knn = cross_val_score(knn,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",knn)

#---------------------------------------------knn 1200-----------------------
array= dataset[:1200].values
#array= dataset.values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizek.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
   
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    
print("\nBy using KNN Classifier \n")
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(normalized_X_train,Y_train)
predictions=knn.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc1=accuracy_score(Y_test,predictions)
acck.append(acc1)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f1=f1_score(Y_test, predictions, average="macro")
knn = cross_val_score(knn,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",knn)
 
#----------------------------knn 1800----------------------------------
array= dataset[:1800].values
#array= dataset.values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizek.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    
print("\nBy using KNN Classifier \n")
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(normalized_X_train,Y_train)
predictions=knn.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc1=accuracy_score(Y_test,predictions)
acck.append(acc1)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f1=f1_score(Y_test, predictions, average="macro")
knn = cross_val_score(knn,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",knn)

#-------------------------------------------------------knn 2124------------------
array= dataset[:2124].values
#array= dataset.values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizek.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x

normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    
print("\nBy using KNN Classifier \n")
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(normalized_X_train,Y_train)
predictions=knn.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc1=accuracy_score(Y_test,predictions)
acck.append(acc1)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f1=f1_score(Y_test, predictions, average="macro")
knn = cross_val_score(knn,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",knn)


#----------------------------------NB----------------------------------------

#----------------------NB 600----------------

array= dataset[:600].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizenb.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x

normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    

print("\nBy using Naived BaIsed Classifier \n")
NB=GaussianNB()
NB.fit(normalized_X_train,Y_train)
predictions=NB.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc2=accuracy_score(Y_test,predictions)
accnb.append(acc2)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f2=f1_score(Y_test, predictions, average="macro")
NB = cross_val_score(NB,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",NB)

#---------------------------------------------NB 1200-----------------------
array= dataset[:1200].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizenb.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    

print("\nBy using Naived BaIsed Classifier \n")
NB=GaussianNB()
NB.fit(normalized_X_train,Y_train)
predictions=NB.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc2=accuracy_score(Y_test,predictions)
accnb.append(acc2)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f2=f1_score(Y_test, predictions, average="macro")
NB = cross_val_score(NB,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",NB)

 
#----------------------------NB 1800----------------------------------
array= dataset[:1800].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizenb.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
   
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    

print("\nBy using Naived BaIsed Classifier \n")
NB=GaussianNB()
NB.fit(normalized_X_train,Y_train)
predictions=NB.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc2=accuracy_score(Y_test,predictions)
accnb.append(acc2)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f2=f1_score(Y_test, predictions, average="macro")
NB = cross_val_score(NB,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",NB)

#-------------------------------------------------------NB 2124------------------
array= dataset[:2124].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizenb.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):

    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    

print("\nBy using Naived BaIsed Classifier \n")
NB=GaussianNB()
NB.fit(normalized_X_train,Y_train)
predictions=NB.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc2=accuracy_score(Y_test,predictions)
accnb.append(acc2)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f2=f1_score(Y_test, predictions, average="macro")
NB = cross_val_score(NB,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",NB)


#--------------------------------SVM-------------------------------------------
#----------------------SVM 600----------------

array= dataset[:600].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizesv.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using SVM Classifier \n")
svmClassifier = SVC (kernel='linear')
svmClassifier.fit(normalized_X_train,Y_train)
predictions=svmClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc3=accuracy_score(Y_test,predictions)
accsv.append(acc3)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f3=f1_score(Y_test, predictions, average="macro")
svmClassifier = cross_val_score(svmClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svmClassifier)
#---------------------------------------------SVM 1200-----------------------
array= dataset[:1200].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizesv.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using SVM Classifier \n")
svmClassifier = SVC (kernel='linear')
svmClassifier.fit(normalized_X_train,Y_train)
predictions=svmClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc3=accuracy_score(Y_test,predictions)
accsv.append(acc3)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f3=f1_score(Y_test, predictions, average="macro")
svmClassifier = cross_val_score(svmClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svmClassifier)
 
#----------------------------SVM 1800----------------------------------
array= dataset[:1800].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizesv.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using SVM Classifier \n")
svmClassifier = SVC (kernel='linear')
svmClassifier.fit(normalized_X_train,Y_train)
predictions=svmClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc3=accuracy_score(Y_test,predictions)
accsv.append(acc3)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f3=f1_score(Y_test, predictions, average="macro")
svmClassifier = cross_val_score(svmClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svmClassifier)
#-------------------------------------------------------SVM 2124------------------
array= dataset[:2124].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizesv.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using SVM Classifier \n")
svmClassifier = SVC (kernel='linear')
svmClassifier.fit(normalized_X_train,Y_train)
predictions=svmClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc3=accuracy_score(Y_test,predictions)
accsv.append(acc3)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f3=f1_score(Y_test, predictions, average="macro")
svmClassifier = cross_val_score(svmClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svmClassifier)


#-----------------------------------C4.5----------------------------------------

#----------------------C4.5 600----------------

array= dataset[:600].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizec4.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]





print("\nBy using C4.5 Classifier \n")
c45 = tree.DecisionTreeClassifier() 
c45.fit(normalized_X_train,Y_train)
predictions=c45.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc4=accuracy_score(Y_test,predictions)
accc4.append(acc4)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f4=f1_score(Y_test, predictions, average="macro")
c45 = cross_val_score(c45,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",c45)
#---------------------------------------------C4.5 1200-----------------------
array= dataset[:1200].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizec4.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]





print("\nBy using C4.5 Classifier \n")
c45 = tree.DecisionTreeClassifier() 
c45.fit(normalized_X_train,Y_train)
predictions=c45.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc4=accuracy_score(Y_test,predictions)
accc4.append(acc4)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f4=f1_score(Y_test, predictions, average="macro")
c45 = cross_val_score(c45,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",c45) 
#----------------------------C4.5 1800----------------------------------
array= dataset[:1800].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizec4.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]





print("\nBy using C4.5 Classifier \n")
c45 = tree.DecisionTreeClassifier() 
c45.fit(normalized_X_train,Y_train)
predictions=c45.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc4=accuracy_score(Y_test,predictions)
accc4.append(acc4)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f4=f1_score(Y_test, predictions, average="macro")
c45 = cross_val_score(c45,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",c45)
#-------------------------------------------------------C4.5 2124------------------
array= dataset[:2124].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizec4.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x

normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]





print("\nBy using C4.5 Classifier \n")
c45 = tree.DecisionTreeClassifier() 
c45.fit(normalized_X_train,Y_train)
predictions=c45.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc4=accuracy_score(Y_test,predictions)
accc4.append(acc4)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f4=f1_score(Y_test, predictions, average="macro")
c45 = cross_val_score(c45,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",c45)



#--------------------------RBF GAUSSIAN KERNAL with chi squared------------------------------

#----------------------RBF-C3 600----------------

array= dataset[:600].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizerbf.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using RBF GAUSSIAN KERNAL WITH CHI SQUARED \n")
svcClassifier = svm.SVC(kernel='rbf',C=3)
svcClassifier.fit(normalized_X_train,Y_train)
predictions=svcClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc5=accuracy_score(Y_test,predictions)
accrbf.append(acc5)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f5=f1_score(Y_test, predictions, average="macro")
svcClassifier= cross_val_score(svcClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svcClassifier)
#---------------------------------------------RBF-C3 1200-----------------------
array= dataset[:1200].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizerbf.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using RBF GAUSSIAN KERNAL WITH CHI SQUARED \n")
svcClassifier = svm.SVC(kernel='rbf',C=3)
svcClassifier.fit(normalized_X_train,Y_train)
predictions=svcClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc5=accuracy_score(Y_test,predictions)
accrbf.append(acc5)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f5=f1_score(Y_test, predictions, average="macro")
svcClassifier= cross_val_score(svcClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svcClassifier)
#----------------------------RBF-C3 1800----------------------------------
array= dataset[:1800].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizerbf.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using RBF GAUSSIAN KERNAL WITH CHI SQUARED \n")
svcClassifier = svm.SVC(kernel='rbf',C=3)
svcClassifier.fit(normalized_X_train,Y_train)
predictions=svcClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc5=accuracy_score(Y_test,predictions)
accrbf.append(acc5)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f5=f1_score(Y_test, predictions, average="macro")
svcClassifier= cross_val_score(svcClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svcClassifier)
#-------------------------------------------------------RBF-C3 2124------------------
array= dataset[:2124].values
x=array[:,3:25]
y=array[:,25]
n=len(x)
print(n)
sizerbf.append(n)

scaler=Normalizer().fit(x)
normalized_x= scaler.transform(x)
normalized_x


normalized_X_train , normalized_X_test, Y_train, Y_test= train_test_split(normalized_x,y,test_size=0.30,random_state=8)

kf = KFold(n_splits = 10,random_state=None, shuffle=False)
kf.get_n_splits(normalized_x)

for train_index, test_index in kf.split(normalized_x):
    normalized_X_train, normalized_X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]



print("\nBy using RBF GAUSSIAN KERNAL WITH CHI SQUARED \n")
svcClassifier = svm.SVC(kernel='rbf',C=3)
svcClassifier.fit(normalized_X_train,Y_train)
predictions=svcClassifier.predict(normalized_X_test)
print("\nACCURACY:",accuracy_score(Y_test,predictions))
acc5=accuracy_score(Y_test,predictions)
accrbf.append(acc5)
print("\nCONFUSION MATRIX:")
print(confusion_matrix(Y_test,predictions))
print("\nF-MEASURE:",f1_score(Y_test, predictions, average="macro"))
f5=f1_score(Y_test, predictions, average="macro")
svcClassifier= cross_val_score(svcClassifier,normalized_X_train,Y_train,cv=10)
print("Cross Validation :",svcClassifier)



#-----------------PERFORMANCE CURVE---------------------------------
plotgraph.figure(figsize=(8,5))
plotgraph.title('KNN VS NAIVE BAYES VS VS SVM VS C4.5 VS RBF(C=3)', fontdict={'fontweight':'bold', 'fontsize': 18})
plotgraph.plot(sizek, acck, color='blue', label='KNN')
plotgraph.plot(sizenb, accnb, color='yellow', label='NAIVE BAYES')
plotgraph.plot(sizesv, accsv, color='green',label='SVM')
plotgraph.plot(sizec4, accc4, color='orange',label='C4.5')
plotgraph.plot(sizerbf, accrbf, color='purple',label='RBF(C3)')
plotgraph.xlabel('NUMBER OF TRAINING DATA')
plotgraph.ylabel('ACCURACY')
plotgraph.legend()
plotgraph.savefig('PERFORMANCE CURVE.png', dpi=300)
plotgraph.show()

#-----------------------Graph Accuracy-----------------------------

plotaccuracy.title('ACCURACY SCORE')
Classifier = ['KNN', 'NAIVE BAIYER', 'SVM','C4.5','SVM RBF KERNAL']
Accuracy = [acc1,acc2,acc3,acc4,acc5]
bars = plotaccuracy.bar(Classifier, Accuracy)
plotaccuracy.show()

#-----------------------Graph fmeasure-----------------------------

plotfmeasure.title('F-MEASURE')
Fmeasure = [f1,f2,f3,f4,f5]
bars = plotfmeasure.bar(Classifier, Fmeasure)
plotfmeasure.show()
# Out:
# 600
#
# By using KNN Classifier
#
#
# ACCURACY: 0.9166666666666666
#
# CONFUSION MATRIX:
# [[46  2  0]
#  [ 1  9  0]
#  [ 0  2  0]]
#
# F-MEASURE: 0.5836765827612509
# Cross Validation : [0.75925926 0.61111111 0.68518519 0.85185185 0.92592593 0.85185185
#  0.87037037 0.85185185 0.7962963  0.74074074]
# 1200
#
# By using KNN Classifier
#
#
# ACCURACY: 1.0
#
# CONFUSION MATRIX:
# [[120]]
#
# F-MEASURE: 1.0
# Cross Validation : [0.78703704 0.72222222 0.94444444 0.83333333 0.87962963 0.86111111
#  0.69444444 0.74074074 0.89814815 0.90740741]
# 1800
#
# By using KNN Classifier
#
#
# ACCURACY: 0.8166666666666667
#
# CONFUSION MATRIX:
# [[137   5   0]
#  [  0   0   0]
#  [ 28   0  10]]
#
# F-MEASURE: 0.4363916033297141
# Cross Validation : [0.85802469 0.87654321 0.89506173 0.87037037 0.83950617 0.87037037
#  0.88271605 0.94444444 0.85802469 0.7654321 ]
# 2124
#
# By using KNN Classifier
#
#
# ACCURACY: 0.7783018867924528
#
# CONFUSION MATRIX:
# [[131  31   9]
#  [  2   1   1]
# ...
