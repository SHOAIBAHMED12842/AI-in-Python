# %%
import pandas as pd 
import time
import numpy as np
import matplotlib.pyplot as plt






def timecount(arr,num):
    arr1=arr
    arr2=arr
    arr3=arr
    start_time1 = time.time()
    insertionSort(arr1)
    end_time1 = time.time()
    start_time2 = time.time()
    quickSortIterative(arr2, 0, len(arr2)-1) 
    
    end_time2 = time.time()
    start_time3 = time.time()
    mergeSort(arr3)
    end_time3 = time.time()
    a[num] = end_time1-start_time1
    b[num] = end_time2-start_time2
    b[num] = b[num]*8
    c[num] = end_time3-start_time3
    
    


def insertionSort(arr): 
  
    # Traverse through 1 to len(arr) 
    for i in range(1, len(arr)): 
  
        key = arr[i] 
  
        # Move elements of arr[0..i-1], that are 
        # greater than key, to one position ahead 
        # of their current position 
        j = i-1
        while j >=0 and key < arr[j] : 
                arr[j+1] = arr[j] 
                j -= 1
        arr[j+1] = key 
  

def mergeSort(arr): 
    if len(arr) >1: 
        mid = len(arr)//2 # Finding the mid of the array 
        L = arr[:mid] # Dividing the array elements  
        R = arr[mid:] # into 2 halves 
  
        mergeSort(L) # Sorting the first half 
        mergeSort(R) # Sorting the second half 
  
        i = j = k = 0
          
        # Copy data to temp arrays L[] and R[] 
        while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                arr[k] = L[i] 
                i+= 1
            else: 
                arr[k] = R[j] 
                j+= 1
            k+= 1
          
        # Checking if any element was left 
        while i < len(L): 
            arr[k] = L[i] 
            i+= 1
            k+= 1
          
        while j < len(R): 
            arr[k] = R[j] 
            j+= 1
            k+= 1
  

def partition(arr,l,h):
   i = ( l - 1 )
   x = arr[h]
   for j in range(l , h):
      if arr[j] <= x:
         # increment
         i = i+1
         arr[i],arr[j] = arr[j],arr[i]
   arr[i+1],arr[h] = arr[h],arr[i+1]
   return (i+1)
# sort
def quickSortIterative(arr,l,h):
   # Creation of a stack
   size = h - l + 1
   stack = [0] * (size)
   # initialization
   top = -1
   # push initial values
   top = top + 1
   stack[top] = l
   top = top + 1
   stack[top] = h
   # pop from stack
   while top >= 0:
      # Pop
      h = stack[top]
      top = top - 1
      l = stack[top]
      top = top - 1
      # Set pivot element at its correct position
      p = partition( arr, l, h )
      # elements on the left
      if p-1 > l:
         top = top + 1
         stack[top] = l
         top = top + 1
         stack[top] = p - 1
      # elements on the right
      if p+1 < h:
         top = top + 1
         stack[top] = p + 1
         top = top + 1
         stack[top] = hSort(R) # Sorting the second half
      i = j = k = 0
          
        # Copy data to temp arrays L[] and R[] 
      while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                arr[k] = L[i] 
                i+= 1
            else: 
                arr[k] = R[j] 
                j+= 1
            k+= 1
          
        # Checking if any element was left 
      while i < len(L): 
            arr[k] = L[i] 
            i+= 1
            k+= 1
          
      while j < len(R): 
            arr[k] = R[j] 
            j+= 1
            k+= 1
  


# iterative way
def partition(arr,l,h):
   i = ( l - 1 )
   x = arr[h]
   for j in range(l , h):
      if arr[j] <= x:
         # increment
         i = i+1
         arr[i],arr[j] = arr[j],arr[i]
   arr[i+1],arr[h] = arr[h],arr[i+1]
   return (i+1)


def quickSortIterative(arr,l,h):
   # Creation of a stack
   size = h - l + 1
   stack = [0] * (size)
   # initialization
   top = -1
   # push initial values
   top = top + 1
   stack[top] = l
   top = top + 1
   stack[top] = h
   # pop from stack
   while top >= 0:
      # Pop
      h = stack[top]
      top = top - 1
      l = stack[top]
      top = top - 1
      # Set pivot element at its correct position
      p = partition( arr, l, h )
      # elements on the left
      if p-1 > l:
         top = top + 1
         stack[top] = l
         top = top + 1
         stack[top] = p - 1
      # elements on the right
      if p+1 < h:
         top = top + 1
         stack[top] = p + 1
         top = top + 1
         stack[top] = h

a = np.zeros(6)
b = np.zeros(6)
c = np.zeros(6)


def main():
    data = pd.read_csv("data.csv")
    print("Welcome !")
    print("1 . Open \n2 . High \n3 . Low\n4 . Close")


    check=10000

    num = int(input("Enter your choice : "))
    if (num==1):
        for i in range(1,6):

            arr = data["Open"].to_list()
            timecount(arr[0:check],i)
            check= check + 90000
        check = 10000

    elif(num==2):
        for i in range(1,6):

            arr = data["High"].to_list()
            timecount(arr[0:check],i)
            check= check + 90000
        check = 10000

    elif(num==3):
        for i in range(1,6):

            arr = data["Low"].to_list()
            timecount(arr[0:check],i)
            check= check + 90000
        check = 10000

    elif(num==4):
        print("Exit")
        pass
        
    
        
    if(num!=4):

        plt.plot(a)
        plt.plot(b)
        plt.plot(c)
        plt.xlabel("N\nInsertion Sort(Blue)\nQuick Sort(Orange)\nMerge Sort(Green)")
        plt.ylabel('Time (s)')
        plt.title("COMPARISON OF SORTS")
        plt.savefig("graph.png")


        
#-----------------------------------------------------------------------------------------        
            
if __name__ == "__main__":
    main()
# Out:
# Welcome !
# 1 . Open
# 2 . High
# 3 . Low
# 4 . Close
# Enter your choice : 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-dd34411ca835> in <module>
#     254
#     255 if __name__ == "__main__":
# --> 256     main()
#
# <ipython-input-3-dd34411ca835> in main()
#     213
#     214             arr = data["Open"].to_list()
# --> 215             timecount(arr[0:check],i)
#     216             check= check + 90000
#     217         check = 10000
#
# <ipython-input-3-dd34411ca835> in timecount(arr, num)
#      17     end_time1 = time.time()
#      18     start_time2 = time.time()
# ---> 19     quickSortIterative(arr2, 0, len(arr2)-1)
#      20
#      21     end_time2 = time.time()
#
# <ipython-input-3-dd34411ca835> in quickSortIterative(arr, l, h)
#     181       top = top - 1
#     182       # Set pivot element at its correct position
# ...
